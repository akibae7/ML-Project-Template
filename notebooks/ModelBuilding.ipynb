# %% [markdown]
# **MODEL BUILDING**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded=files.upload()
import io

df =pd.read_csv(io.BytesIO(uploaded['mobile_price_classification.csv']))
df
# Out:
#      <input type="file" id="files-5fcdaaed-873a-4ff8-a84d-aeb27af3f566" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5fcdaaed-873a-4ff8-a84d-aeb27af3f566">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving mobile_price_classification.csv to mobile_price_classification (2).csv
#       battery_power  blue  clock_speed  ...  touch_screen  wifi  price_range
# 0               842     0          2.2  ...             0     1            1
# 1              1021     1          0.5  ...             1     0            2
# 2               563     1          0.5  ...             1     0            2
# 3               615     1          2.5  ...             0     0            2
# 4              1821     1          1.2  ...             1     0            1
# ...             ...   ...          ...  ...           ...   ...          ...
# 1995            794     1          0.5  ...             1     0            0
# 1996           1965     1          2.6  ...             1     1            2
# 1997           1911     0          0.9  ...             1     0            3
# 1998           1512     0          0.9  ...             1     1            0
# 1999            510     1          2.0  ...             1     1            3
#
# [2000 rows x 21 columns]

# %%
df.shape
# Out:
# (2000, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
#  18  touch_screen   2000 non-null   int64
#  19  wifi           2000 non-null   int64
#  20  price_range    2000 non-null   int64
# dtypes: float64(2), int64(19)
# memory usage: 328.2 KB

# %%
#Featrures 
X = pd.DataFrame(df.iloc[:, 1:-1])
X
# Out:
#       blue  clock_speed  dual_sim  fc  ...  talk_time  three_g  touch_screen  wifi
# 0        0          2.2         0   1  ...         19        0             0     1
# 1        1          0.5         1   0  ...          7        1             1     0
# 2        1          0.5         1   2  ...          9        1             1     0
# 3        1          2.5         0   0  ...         11        1             0     0
# 4        1          1.2         0  13  ...         15        1             1     0
# ...    ...          ...       ...  ..  ...        ...      ...           ...   ...
# 1995     1          0.5         1   0  ...         19        1             1     0
# 1996     1          2.6         1   0  ...         16        1             1     1
# 1997     0          0.9         1   1  ...          5        1             1     0
# 1998     0          0.9         0   4  ...         19        1             1     1
# 1999     1          2.0         1   5  ...          2        1             1     1
#
# [2000 rows x 19 columns]

# %%
#Target
y = pd.DataFrame(df.iloc[:,-1])
y
# Out:
#       price_range
# 0               1
# 1               2
# 2               2
# 3               2
# 4               1
# ...           ...
# 1995            0
# 1996            2
# 1997            3
# 1998            0
# 1999            3
#
# [2000 rows x 1 columns]

# %% [markdown]
# # **KNN**
#
# ---

# %%
# Split dataset into training set and test set

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.neighbors import KNeighborsClassifier
clf = KNeighborsClassifier(n_neighbors=5)
clf.fit(X_train, y_train.values.ravel())
# Out:
# KNeighborsClassifier()

# %%
y_pred = clf.predict(X_test)

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.78

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
# [[89 10  0  0]
#  [15 73 11  0]
#  [ 0 19 82 18]
#  [ 0  0 15 68]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88        99
#            1       0.72      0.74      0.73        99
#            2       0.76      0.69      0.72       119
#            3       0.79      0.82      0.80        83
#
#     accuracy                           0.78       400
#    macro avg       0.78      0.79      0.78       400
# weighted avg       0.78      0.78      0.78       400
#
# 0.78

# %% [markdown]
# # **NAIVE BAYES**
#
# ---

# %%
# splitting X and y into training and testing sets 
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1)

# %%
y_test
# Out:
#       price_range
# 674             0
# 1699            0
# 1282            1
# 1315            1
# 1210            2
# ...           ...
# 1816            3
# 390             3
# 1992            0
# 78              3
# 1410            1
#
# [800 rows x 1 columns]

# %%
# training the model on training set 
from sklearn.naive_bayes import GaussianNB 
gnb = GaussianNB() 
gnb.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GaussianNB()

# %%
# making predictions on the testing set 
y_pred = gnb.predict(X_test)
y_pred
# Out:
# array([0, 1, 1, 0, 3, 1, 1, 2, 2, 3, 0, 3, 1, 1, 3, 0, 1, 1, 0, 2, 3, 3,
#        1, 2, 3, 2, 2, 3, 2, 2, 2, 1, 3, 0, 3, 3, 0, 0, 1, 1, 1, 0, 2, 1,
#        0, 1, 3, 2, 2, 2, 2, 3, 1, 3, 2, 3, 2, 3, 3, 1, 0, 2, 1, 2, 1, 2,
#        1, 2, 3, 3, 1, 2, 0, 2, 3, 1, 2, 1, 0, 0, 0, 3, 2, 2, 3, 2, 3, 1,
#        2, 1, 3, 0, 1, 2, 1, 2, 3, 0, 2, 3, 3, 3, 0, 2, 2, 1, 1, 1, 0, 2,
#        0, 3, 1, 1, 2, 2, 3, 1, 1, 1, 2, 0, 0, 0, 3, 0, 1, 0, 1, 1, 0, 3,
#        0, 3, 3, 0, 3, 2, 1, 1, 0, 0, 2, 1, 0, 3, 0, 1, 0, 1, 3, 3, 2, 1,
#        0, 1, 1, 0, 2, 1, 3, 1, 3, 2, 3, 1, 2, 1, 3, 2, 2, 0, 2, 2, 0, 3,
#        3, 0, 0, 3, 0, 3, 0, 0, 2, 3, 3, 1, 2, 2, 2, 3, 1, 2, 1, 1, 2, 3,
#        3, 1, 3, 2, 0, 1, 2, 1, 2, 1, 1, 1, 0, 2, 1, 0, 2, 0, 1, 0, 1, 1,
#        0, 1, 2, 1, 3, 3, 1, 2, 2, 1, 1, 2, 3, 3, 2, 1, 0, 1, 2, 1, 2, 3,
#        2, 2, 0, 1, 2, 0, 3, 3, 3, 0, 2, 1, 0, 1, 1, 3, 2, 0, 3, 1, 1, 1,
#        2, 1, 2, 0, 3, 2, 2, 0, 0, 1, 2, 3, 1, 1, 1, 3, 3, 1, 1, 2, 2, 0,
#        0, 3, 0, 0, 1, 3, 2, 3, 0, 0, 1, 3, 3, 2, 1, 2, 0, 0, 3, 1, 1, 0,
#        0, 0, 2, 2, 2, 1, 0, 1, 2, 1, 3, 3, 3, 1, 1, 2, 2, 1, 1, 0, 2, 3,
#        3, 1, 1, 0, 1, 1, 3, 2, 0, 3, 2, 2, 2, 3, 1, 2, 3, 2, 3, 2, 0, 3,
#        0, 0, 3, 1, 3, 2, 3, 3, 3, 0, 3, 0, 1, 1, 2, 3, 0, 0, 2, 3, 1, 0,
#        2, 3, 3, 0, 2, 2, 1, 3, 2, 3, 3, 0, 3, 2, 0, 0, 3, 3, 2, 0, 3, 2,
#        3, 3, 1, 0, 2, 0, 0, 0, 1, 1, 2, 1, 2, 3, 0, 1, 1, 3, 3, 3, 2, 3,
#        3, 3, 3, 2, 0, 1, 2, 1, 2, 2, 2, 1, 1, 0, 3, 2, 1, 1, 0, 0, 2, 2,
#        0, 3, 3, 1, 1, 3, 0, 2, 3, 0, 2, 3, 1, 1, 2, 0, 2, 1, 3, 2, 0, 1,
#        0, 2, 0, 3, 1, 2, 1, 2, 0, 1, 1, 2, 1, 2, 1, 0, 1, 1, 0, 2, 1, 1,
#        3, 1, 3, 1, 2, 0, 2, 1, 2, 0, 2, 2, 0, 0, 2, 0, 2, 1, 1, 2, 0, 3,
#        1, 3, 0, 3, 0, 1, 0, 0, 1, 0, 3, 1, 3, 2, 1, 3, 3, 3, 3, 1, 0, 3,
#        3, 1, 1, 1, 2, 0, 1, 2, 3, 3, 0, 1, 0, 1, 0, 0, 0, 2, 2, 1, 1, 2,
#        3, 1, 1, 3, 1, 2, 2, 0, 3, 1, 2, 0, 2, 2, 3, 2, 2, 3, 2, 2, 0, 1,
#        1, 3, 3, 1, 3, 0, 2, 3, 1, 0, 2, 2, 0, 2, 2, 2, 1, 3, 3, 2, 3, 0,
#        2, 0, 2, 2, 3, 3, 1, 0, 0, 1, 1, 2, 2, 2, 0, 3, 1, 0, 2, 3, 1, 3,
#        2, 2, 1, 1, 2, 3, 0, 3, 1, 2, 1, 2, 3, 3, 1, 0, 0, 1, 1, 2, 0, 1,
#        0, 0, 0, 1, 3, 2, 0, 2, 3, 2, 2, 1, 2, 1, 0, 3, 0, 0, 2, 3, 2, 1,
#        0, 0, 1, 3, 2, 3, 3, 2, 1, 2, 0, 2, 0, 2, 1, 0, 1, 1, 3, 3, 3, 0,
#        1, 3, 3, 2, 0, 1, 0, 1, 0, 1, 2, 2, 0, 1, 0, 3, 0, 1, 2, 1, 0, 2,
#        3, 3, 2, 3, 0, 0, 2, 2, 3, 2, 3, 0, 0, 0, 3, 1, 0, 3, 3, 3, 2, 1,
#        3, 3, 1, 3, 1, 1, 2, 2, 1, 0, 3, 2, 0, 1, 3, 3, 3, 0, 0, 0, 3, 0,
#        0, 0, 3, 2, 0, 2, 2, 3, 2, 3, 1, 1, 0, 2, 1, 1, 3, 2, 0, 0, 1, 2,
#        0, 2, 3, 2, 1, 3, 1, 0, 2, 1, 2, 2, 2, 2, 3, 2, 3, 3, 1, 3, 0, 0,
#        2, 0, 2, 3, 2, 0, 3, 2])

# %%
# comparing actual response values (y_test) with predicted response values (y_pred) 
from sklearn import metrics 
print("Gaussian Naive Bayes model accuracy(in %):", metrics.accuracy_score(y_test, y_pred)*100)
# Out:
# Gaussian Naive Bayes model accuracy(in %): 77.75

# %% [markdown]
# # **DECISION TREE**
#
# ---

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
# Split dataset into training set and test set

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
DT_classifier = DecisionTreeClassifier()
DT_classifier.fit(X_train, y_train)
DT_Predictions = DT_classifier.predict(X_test)

# %%
accuracy_score(DT_Predictions, y_test)
# Out:
# 0.74

# %% [markdown]
# # **LOGISTIC REGRESSION**
#
# ---

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR_clsifier = LogisticRegression(solver='lbfgs', max_iter=1000)
LR_clsifier.fit(X_train, y_train)
LR_Predictions = LR_clsifier.predict(X_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,

# %%
accuracy_score(LR_Predictions, y_test)
# Out:
# 0.7175
